# %% [raw]
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "id": "initial_id",
#    "metadata": {
#     "collapsed": true,
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:35:04.946262Z",
#      "start_time": "2025-05-20T13:35:04.943971Z"
#     }
#    },
#    "source": [
#     "from cProfile import label\n",
#     "\n",
#     "import numpy as np\n",
#     "import scipy\n",
#     "from scipy.sparse import csr_matrix\n",
#     "from gudhi import CubicalComplex\n",
#     "from gudhi.sklearn.cubical_persistence import CubicalPersistence\n",
#     "from medmnist import ChestMNIST\n",
#     "from PIL import Image\n",
#     "import time\n",
#     "import matplotlib.pyplot as plt\n",
#     "from scipy.stats import tiecorrect\n",
#     "\n",
#     "from my_tools_np import *\n",
#     "from sparse_uplap import *"
#    ],
#    "outputs": [],
#    "execution_count": 30
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.192649Z",
#      "start_time": "2025-05-20T13:28:45.485747Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "test_dataset = ChestMNIST(split=\"test\", download=False, size=224)",
#    "id": "e2291cb4e313b4c2",
#    "outputs": [],
#    "execution_count": 3
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.206759Z",
#      "start_time": "2025-05-20T13:28:50.204528Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "image, y = test_dataset[0]",
#    "id": "985ff19332a3e500",
#    "outputs": [],
#    "execution_count": 4
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.230833Z",
#      "start_time": "2025-05-20T13:28:50.217142Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "image",
#    "id": "9b26f78373a0f3e8",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "<PIL.Image.Image image mode=L size=224x224>"
#       ],
#       "image/png": "...",
#       "image/jpeg": "..."
#      },
#      "execution_count": 5,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 5
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.252326Z",
#      "start_time": "2025-05-20T13:28:50.249456Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "np.array(image).shape",
#    "id": "fcab04c14f803d5c",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "(224, 224)"
#       ]
#      },
#      "execution_count": 6,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 6
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.269225Z",
#      "start_time": "2025-05-20T13:28:50.267490Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "image_array = np.array(image)",
#    "id": "97eef10016ef45cf",
#    "outputs": [],
#    "execution_count": 7
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.280776Z",
#      "start_time": "2025-05-20T13:28:50.278370Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "image_array.min()",
#    "id": "16d7057705a4cc28",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "0"
#       ]
#      },
#      "execution_count": 8,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 8
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.303947Z",
#      "start_time": "2025-05-20T13:28:50.301336Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "image_array.max()",
#    "id": "74f7777e40bdf287",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "245"
#       ]
#      },
#      "execution_count": 9,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 9
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.327437Z",
#      "start_time": "2025-05-20T13:28:50.325172Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "image_array = 245 - image_array",
#    "id": "e0f250f486d2b00d",
#    "outputs": [],
#    "execution_count": 10
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.463362Z",
#      "start_time": "2025-05-20T13:28:50.340835Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "img = Image.fromarray(image_array)\n",
#     "img.show()"
#    ],
#    "id": "7329b30f48e5654e",
#    "outputs": [],
#    "execution_count": 11
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.479271Z",
#      "start_time": "2025-05-20T13:28:50.475147Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "pool_size = (2, 2)\n",
#     "\n",
#     "image_array_2 = max_pool2d(image_array, pool_size, pool_size)\n",
#     "image_array_3 = max_pool2d(image_array_2, pool_size, pool_size)\n",
#     "image_array_4 = max_pool2d(image_array_3, pool_size, pool_size)\n",
#     "image_array_5 = max_pool2d(image_array_4, pool_size, pool_size)\n",
#     "image_array_6 = max_pool2d(image_array_5, pool_size, pool_size)\n",
#     "image_array_7 = max_pool2d(image_array_6, pool_size, pool_size)\n",
#     "image_array_8 = max_pool2d(image_array_7, pool_size, pool_size)"
#    ],
#    "id": "e542f5276753c9e4",
#    "outputs": [],
#    "execution_count": 12
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.506893Z",
#      "start_time": "2025-05-20T13:28:50.491720Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "X = CubicalComplex(top_dimensional_cells=image_array).all_cells()",
#    "id": "95a6ea67a420255d",
#    "outputs": [],
#    "execution_count": 13
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.520486Z",
#      "start_time": "2025-05-20T13:28:50.517077Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "X.shape",
#    "id": "af372d4c2d4b0f04",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "(449, 449)"
#       ]
#      },
#      "execution_count": 14,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 14
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.577425Z",
#      "start_time": "2025-05-20T13:28:50.538705Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "bdry_opr, filt_idx_0_2, filt_idx_1_2, num_filt = get_bdry_opr(X, filt_0=20, filt_1=50, filt_2=150)\n",
#     "# bdry_opr, filt_idx_0_2, filt_idx_1_2, num_filt = get_bdry_opr(X, filt_0=50, filt_1=60, filt_2=80)"
#    ],
#    "id": "4fc5d1f096a5a249",
#    "outputs": [],
#    "execution_count": 15
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.589746Z",
#      "start_time": "2025-05-20T13:28:50.586451Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "num_filt",
#    "id": "89bc037ff17c38a9",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "47211"
#       ]
#      },
#      "execution_count": 16,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 16
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.606824Z",
#      "start_time": "2025-05-20T13:28:50.603801Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "bdry_opr.shape",
#    "id": "ce807b0d1b947577",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "(63366, 31028)"
#       ]
#      },
#      "execution_count": 17,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 17
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.626280Z",
#      "start_time": "2025-05-20T13:28:50.623874Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "filt_idx_1_2",
#    "id": "6c31e993a87043ca",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "array([False, False, False, ..., False, False, False])"
#       ]
#      },
#      "execution_count": 18,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 18
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:28:50.654544Z",
#      "start_time": "2025-05-20T13:28:50.648848Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "sum(filt_idx_1_2)",
#    "id": "e1bed6c3441e56a5",
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "16155"
#       ]
#      },
#      "execution_count": 19,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "execution_count": 19
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:29:22.968795Z",
#      "start_time": "2025-05-20T13:28:50.677943Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "uplapclass = UpPersistentLaplacianSparse(bdry_opr, filt_idx_0_2=filt_idx_1_2,\n",
#     "                                         filt_idx_1_2=np.ones(bdry_opr.shape[0], dtype=bool))\n",
#     "time_list_1 = []\n",
#     "\n",
#     "st_1 = time.time()\n",
#     "\n",
#     "uplapclass.find_D()\n",
#     "uplapclass.find_root()\n",
#     "uplapclass.uf.find_loops()\n",
#     "uplapclass.uf.find_loops_roots()\n",
#     "uplapclass.find_rel_bdry_opr()\n",
#     "uplapclass.find_diag()\n",
#     "\n",
#     "# temp_D = uplapclass.rel_bdry_opr @ np.sqrt(uplapclass.diag)\n",
#     "# uplapclass.find_up_persistent_Laplacian()\n",
#     "\n",
#     "for i in range(num_filt):\n",
#     "    uplapclass.add_edge_temp()\n",
#     "    if i % 100 == 0:\n",
#     "        ed_1 = time.time()\n",
#     "        time_list_1.append(ed_1 - st_1)\n",
#     "\n",
#     "\n",
#     "et_1 = time.time()\n",
#     "time_list_1.append(et_1 - st_1)"
#    ],
#    "id": "fbb9c4735d79a11e",
#    "outputs": [],
#    "execution_count": 20
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:30:02.024460Z",
#      "start_time": "2025-05-20T13:29:22.978519Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "uplapclass = UpPersistentLaplacianSparse(bdry_opr, filt_idx_0_2=filt_idx_1_2,\n",
#     "                                         filt_idx_1_2=np.ones(bdry_opr.shape[0], dtype=bool))\n",
#     "time_list_2 = []\n",
#     "st_1 = time.time()\n",
#     "\n",
#     "uplapclass.find_D()\n",
#     "uplapclass.find_root()\n",
#     "uplapclass.uf.find_loops()\n",
#     "uplapclass.uf.find_loops_roots()\n",
#     "uplapclass.find_rel_bdry_opr()\n",
#     "uplapclass.find_diag()\n",
#     "\n",
#     "d = np.sqrt(uplapclass.diag_array)  # Replace with your diagonal entries\n",
#     "rel_bdry_opr_scaled = uplapclass.rel_bdry_opr.data * d[uplapclass.rel_bdry_opr.indices]\n",
#     "temp_D = sp.csr_matrix((rel_bdry_opr_scaled, uplapclass.rel_bdry_opr.indices, uplapclass.rel_bdry_opr.indptr), shape=uplapclass.rel_bdry_opr.shape)\n",
#     "\n",
#     "# temp_D = uplapclass.rel_bdry_opr @ np.sqrt(uplapclass.diag)\n",
#     "# uplapclass.find_up_persistent_Laplacian()\n",
#     "\n",
#     "for i in range(num_filt):\n",
#     "    uplapclass.add_edge_temp()\n",
#     "\n",
#     "    d = np.sqrt(uplapclass.diag_array)  # Replace with your diagonal entries\n",
#     "    rel_bdry_opr_scaled = uplapclass.rel_bdry_opr.data * d[uplapclass.rel_bdry_opr.indices]\n",
#     "    temp_D = sp.csr_matrix((rel_bdry_opr_scaled, uplapclass.rel_bdry_opr.indices, uplapclass.rel_bdry_opr.indptr), shape=uplapclass.rel_bdry_opr.shape)\n",
#     "    if i % 100 == 0:\n",
#     "        ed_1 = time.time()\n",
#     "        time_list_2.append(ed_1 - st_1)\n",
#     "\n",
#     "    # temp_D = uplapclass.rel_bdry_opr @ np.sqrt(uplapclass.diag)\n",
#     "    # uplapclass.find_up_persistent_Laplacian()\n",
#     "\n",
#     "et_1 = time.time()\n",
#     "et_1 - st_1\n",
#     "time_list_2.append(et_1 - st_1)"
#    ],
#    "id": "585844a8542074a0",
#    "outputs": [],
#    "execution_count": 21
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:32:13.339632Z",
#      "start_time": "2025-05-20T13:30:02.034642Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "uplapclass = UpPersistentLaplacianSparse(bdry_opr, filt_idx_0_2=filt_idx_1_2,\n",
#     "                                         filt_idx_1_2=np.ones(bdry_opr.shape[0], dtype=bool))\n",
#     "time_list_3 = []\n",
#     "st_1 = time.time()\n",
#     "\n",
#     "uplapclass.find_D()\n",
#     "uplapclass.find_root()\n",
#     "uplapclass.uf.find_loops()\n",
#     "uplapclass.uf.find_loops_roots()\n",
#     "uplapclass.find_rel_bdry_opr()\n",
#     "uplapclass.find_diag()\n",
#     "uplapclass.find_up_persistent_Laplacian()\n",
#     "\n",
#     "for i in range(num_filt):\n",
#     "    uplapclass.add_edge_temp()\n",
#     "    uplapclass.find_up_persistent_Laplacian()\n",
#     "    if i % 100 == 0:\n",
#     "        ed_1 = time.time()\n",
#     "        time_list_3.append(ed_1 - st_1)\n",
#     "\n",
#     "et_1 = time.time()\n",
#     "time_list_3.append(et_1 - st_1)"
#    ],
#    "id": "c3a8f1580f2b6f0a",
#    "outputs": [],
#    "execution_count": 22
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:35:04.135Z",
#      "start_time": "2025-05-20T13:32:13.356717Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "time_list_4 = []\n",
#     "st_2 = time.time()\n",
#     "\n",
#     "sub_filt_idx = np.where(uplapclass.filt_idx_1_2 != uplapclass.filt_idx_0_2)[0]\n",
#     "indices_it = iter(sub_filt_idx)\n",
#     "M = bdry_opr @ np.transpose(bdry_opr)\n",
#     "\n",
#     "for i in range(num_filt):\n",
#     "    edge = next(indices_it)\n",
#     "    M = compute_up_persistent(M, edge - i)\n",
#     "    if i % 100 == 0:\n",
#     "        ed_2 = time.time()\n",
#     "        time_list_4.append(ed_2 - st_2)\n",
#     "et_2 = time.time()\n",
#     "time_list_4.append(et_2 - st_2)"
#    ],
#    "id": "42e2095820afae5c",
#    "outputs": [],
#    "execution_count": 23
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:35:04.148425Z",
#      "start_time": "2025-05-20T13:35:04.146547Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "steps = [_ for _ in range(0, num_filt, 100)]\n",
#     "steps.append(num_filt)"
#    ],
#    "id": "9c8641f6a54ea31",
#    "outputs": [],
#    "execution_count": 24
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:42:35.232913Z",
#      "start_time": "2025-05-20T13:42:35.097616Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "plt.rcParams['text.usetex'] = True\n",
#     "\n",
#     "plt.plot(steps, time_list_1, label='Computing pairs of $(B_{1}^{\\mathcal{L}, \\mathcal{K}}, W_{1}^{\\mathcal{L}, \\mathcal{K}})$')\n",
#     "plt.plot(steps, time_list_2, label='Computing $B_{1}^{\\mathcal{L}, \\mathcal{K}}(W_{1}^{\\mathcal{L}, \\mathcal{K}})^{1/2}$')\n",
#     "plt.plot(steps, time_list_3, label='Computing $\\Delta_{1, up}^{\\mathcal{K}, \\mathcal{L}}$ using DSU algorithm')\n",
#     "plt.plot(steps, time_list_4, label='Computing $\\Delta_{1, up}^{\\mathcal{K}, \\mathcal{L}}$ using Schur complement')\n",
#     "\n",
#     "plt.xlabel('$n$')\n",
#     "plt.ylabel('Time (s)')\n",
#     "plt.legend()\n",
#     "# plt.show()\n",
#     "plt.savefig('plots/computing_time_1.png')"
#    ],
#    "id": "532bf54aafdf5633",
#    "outputs": [
#     {
#      "name": "stderr",
#      "output_type": "stream",
#      "text": [
#       "<>:3: SyntaxWarning: invalid escape sequence '\\m'\n",
#       "<>:4: SyntaxWarning: invalid escape sequence '\\m'\n",
#       "<>:5: SyntaxWarning: invalid escape sequence '\\D'\n",
#       "<>:6: SyntaxWarning: invalid escape sequence '\\D'\n",
#       "<>:3: SyntaxWarning: invalid escape sequence '\\m'\n",
#       "<>:4: SyntaxWarning: invalid escape sequence '\\m'\n",
#       "<>:5: SyntaxWarning: invalid escape sequence '\\D'\n",
#       "<>:6: SyntaxWarning: invalid escape sequence '\\D'\n",
#       "/var/folders/n1/2nx4r24j3cgfs0dtl42x1kfr0000gn/T/ipykernel_50580/1806112101.py:3: SyntaxWarning: invalid escape sequence '\\m'\n",
#       "  plt.plot(steps, time_list_1, label='Computing pairs of $(B_{1}^{\\mathcal{L}, \\mathcal{K}}, W_{1}^{\\mathcal{L}, \\mathcal{K}})$')\n",
#       "/var/folders/n1/2nx4r24j3cgfs0dtl42x1kfr0000gn/T/ipykernel_50580/1806112101.py:4: SyntaxWarning: invalid escape sequence '\\m'\n",
#       "  plt.plot(steps, time_list_2, label='Computing $B_{1}^{\\mathcal{L}, \\mathcal{K}}(W_{1}^{\\mathcal{L}, \\mathcal{K}})^{1/2}$')\n",
#       "/var/folders/n1/2nx4r24j3cgfs0dtl42x1kfr0000gn/T/ipykernel_50580/1806112101.py:5: SyntaxWarning: invalid escape sequence '\\D'\n",
#       "  plt.plot(steps, time_list_3, label='Computing $\\Delta_{1, up}^{\\mathcal{K}, \\mathcal{L}}$ using DSU algorithm')\n",
#       "/var/folders/n1/2nx4r24j3cgfs0dtl42x1kfr0000gn/T/ipykernel_50580/1806112101.py:6: SyntaxWarning: invalid escape sequence '\\D'\n",
#       "  plt.plot(steps, time_list_4, label='Computing $\\Delta_{1, up}^{\\mathcal{K}, \\mathcal{L}}$ using Schur complement')\n"
#      ]
#     },
#     {
#      "data": {
#       "text/plain": [
#        "<Figure size 640x480 with 1 Axes>"
#       ],
#       "image/png": "..."
#      },
#      "metadata": {},
#      "output_type": "display_data"
#     }
#    ],
#    "execution_count": 33
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:35:04.843070Z",
#      "start_time": "2025-05-20T13:35:04.841017Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "# # Compute up persistent Laplacian using UF algorithm\n",
#     "# st_1 = time.time()\n",
#     "#\n",
#     "# uplapclass = UpPersistentLaplacianSparse(bdry_opr, filt_idx_0_2=filt_idx_1_2,\n",
#     "#                                          filt_idx_1_2=np.ones(bdry_opr.shape[0], dtype=bool))\n",
#     "# uplapclass.find_D()\n",
#     "# uplapclass.find_root()\n",
#     "# uplapclass.uf.find_loops()\n",
#     "# uplapclass.uf.find_loops_roots()\n",
#     "# uplapclass.find_rel_bdry_opr()\n",
#     "# uplapclass.find_diag()\n",
#     "# # uplapclass.find_up_persistent_Laplacian()\n",
#     "# # print(uplapclass.up_lap.shape)\n",
#     "#\n",
#     "# for j in range(num_filt):\n",
#     "#     uplapclass.add_edge_temp()\n",
#     "#     # uplapclass.find_up_persistent_Laplacian()\n",
#     "#     # print(uplapclass.up_lap.shape)\n",
#     "#     if j % 500 == 0:\n",
#     "#         temp_D = uplapclass.rel_bdry_opr @ np.sqrt(uplapclass.diag)\n",
#     "#         eigs = scipy.sparse.linalg.svds(A=temp_D, k=1, which='SM', return_singular_vectors=False)\n",
#     "#         print(eigs)\n",
#     "#         # print(temp_D.shape)\n",
#     "#\n",
#     "# et_1 = time.time()\n",
#     "#\n",
#     "# et_1 - st_1"
#    ],
#    "id": "19a6d9f3cc1b6e69",
#    "outputs": [],
#    "execution_count": 26
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:35:04.860186Z",
#      "start_time": "2025-05-20T13:35:04.858464Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "# Compute up persistent Laplacian using Memoli's method\n",
#     "# st_2 = time.time()\n",
#     "#\n",
#     "# M = bdry_opr @ np.transpose(bdry_opr)\n",
#     "# # print(M.shape)\n",
#     "# for j in range(num_filt+1):\n",
#     "#     M = compute_up_persistent(M, 0)\n",
#     "#     # print(M.shape)\n",
#     "#     if (j+1) % 500 == 1:\n",
#     "#         # print(M.shape)\n",
#     "#         eigs = scipy.sparse.linalg.eigsh(A=M, k=1, which='SM', return_eigenvectors=False)\n",
#     "#         print(eigs)\n",
#     "#\n",
#     "# et_2 = time.time()\n",
#     "#\n",
#     "# et_2 - st_2"
#    ],
#    "id": "8d88fead361b41dd",
#    "outputs": [],
#    "execution_count": 27
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:35:04.892690Z",
#      "start_time": "2025-05-20T13:35:04.890641Z"
#     }
#    },
#    "cell_type": "code",
#    "source": "# eigs = scipy.sparse.linalg.eigsh(A=M, k=2, which='SM', return_eigenvectors=False)",
#    "id": "8b24b15b00b0f4a1",
#    "outputs": [],
#    "execution_count": 28
#   },
#   {
#    "metadata": {
#     "ExecuteTime": {
#      "end_time": "2025-05-20T13:35:04.929949Z",
#      "start_time": "2025-05-20T13:35:04.927138Z"
#     }
#    },
#    "cell_type": "code",
#    "source": [
#     "# uplapclass = UpPersistentLaplacianSparse(bdry_opr, filt_idx_0_2=filt_idx_1_2,\n",
#     "#                                          filt_idx_1_2=np.ones(bdry_opr.shape[0], dtype=bool))\n",
#     "#\n",
#     "# # st = time.time()\n",
#     "#\n",
#     "# uplapclass.find_D()\n",
#     "# uplapclass.find_root()\n",
#     "# uplapclass.uf.find_loops()\n",
#     "# uplapclass.uf.find_loops_roots()\n",
#     "# uplapclass.find_rel_bdry_opr()\n",
#     "# uplapclass.find_diag()\n",
#     "# uplapclass.find_up_persistent_Laplacian()\n",
#     "#\n",
#     "# sub_filt_idx = np.where(uplapclass.filt_idx_1_2 != uplapclass.filt_idx_0_2)[0]\n",
#     "# indices_it = iter(sub_filt_idx)\n",
#     "# M = bdry_opr @ np.transpose(bdry_opr)\n",
#     "#\n",
#     "# s = np.sum(np.abs((uplapclass.up_lap - M).data))\n",
#     "#\n",
#     "# print(s)\n",
#     "#\n",
#     "# for i in range(num_filt):\n",
#     "#     uplapclass.add_edge_temp()\n",
#     "#     uplapclass.find_up_persistent_Laplacian()\n",
#     "#\n",
#     "#     edge = next(indices_it)\n",
#     "#     M = compute_up_persistent(M, edge - i)\n",
#     "#\n",
#     "#     s = np.sum(np.abs((uplapclass.up_lap - M).data))\n",
#     "#\n",
#     "#     print(s)\n",
#     "#\n",
#     "# # et = time.time()\n",
#     "# # et - st\n"
#    ],
#    "id": "1c2ba27bed29e458",
#    "outputs": [],
#    "execution_count": 29
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python [conda env:dpl] *",
#    "language": "python",
#    "name": "conda-env-dpl-py"
#   },
#   "language_info": {
#    "codemirror_mode": {
#     "name": "ipython",
#     "version": 2
#    },
#    "file_extension": ".py",
#    "mimetype": "text/x-python",
#    "name": "python",
#    "nbconvert_exporter": "python",
#    "pygments_lexer": "ipython2",
#    "version": "2.7.6"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
